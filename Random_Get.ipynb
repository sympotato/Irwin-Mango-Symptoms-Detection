# %%
import os, random, shutil

def copyFile(fileDir):
    pathDir = os.listdir(fileDir)
    sample = random.sample(pathDir, 500)
    for name in sample:
        shutil.copyfile(fileDir+name, tarDir+name)

path = '/home/student/gift/more_500pic/'
num_files = 0
files_name = []
for fn in os.listdir(path):
        num_files += 1
        print(fn)
        files_name=files_name+[fn]
for i in range(0,len(files_name)):
    if not os.path.exists('/home/student/gift/500pic/'+files_name[i]):
           os.makedirs('/home/student/gift/500pic/'+files_name[i])
    fileDir = '/home/student/gift/more_500pic/'+files_name[i]+'/'
    tarDir = '/home/student/gift/500pic/'+files_name[i]+ '/'
    print(fileDir)
    print(tarDir)
    print('---------------')
    copyFile(fileDir)
# Out:
# 28
# 10
# 14
# 7
# 8
# 22
# 1
# 13
# 11
# 25
# 20
# 29
# 5
# 6
# 2
# 21
# 18
# 19
# 15
# 27
# 23
# 26
# 16
# 17
# 0
# 24
# 9
# 4
# 3
# 12
# /home/student/gift/more_500pic/28/
# /home/student/gift/500pic/28/
# ---------------
# /home/student/gift/more_500pic/10/
# /home/student/gift/500pic/10/
# ---------------
# /home/student/gift/more_500pic/14/
# /home/student/gift/500pic/14/
# ---------------
# /home/student/gift/more_500pic/7/
# /home/student/gift/500pic/7/
# ---------------
# /home/student/gift/more_500pic/8/
# /home/student/gift/500pic/8/
# ---------------
# /home/student/gift/more_500pic/22/
# /home/student/gift/500pic/22/
# ---------------
# /home/student/gift/more_500pic/1/
# /home/student/gift/500pic/1/
# ---------------
# /home/student/gift/more_500pic/13/
# /home/student/gift/500pic/13/
# ---------------
# /home/student/gift/more_500pic/11/
# /home/student/gift/500pic/11/
# ---------------
# /home/student/gift/more_500pic/25/
# /home/student/gift/500pic/25/
# ...
